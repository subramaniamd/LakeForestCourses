# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from collections import Counter

# %%
path = r'../Data'
os.listdir(path)
# Out:
# ['alldata.jpg',
#  'alldata2.jpg',
#  'avocado.csv',
#  'Fish.csv',
#  'Lending_Club_DropNA.csv',
#  'MNIST',
#  'MNIST_Fashion',
#  'ramen-ratings.csv',
#  'temps.csv',
#  'testdata.jpg',
#  'testdata2.jpg',
#  'testmask.jpg',
#  'testmask2.jpg',
#  'traindata.jpg',
#  'traindata2.jpg',
#  'trainmask.jpg',
#  'trainmask2.jpg']

# %%
df = pd.read_csv(path + r'/avocado.csv',index_col=0)
df.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8  2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9  2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.9+ MB

# %%
region_list=list(df.region.unique())
x=df[df.region=='West']
x.head()
# Out:
#          Date  AveragePrice  Total Volume        4046        4225       4770  \
# 0  2015-12-27          0.83    5291979.63  2038443.68  1717599.45  125254.82
# 1  2015-12-20          0.88    4737649.03  2017331.24  1314711.00  130849.60
# 2  2015-12-13          0.85    4899439.92  1798995.46  1596329.01  134101.62
# 3  2015-12-06          0.75    6202513.84  2097720.52  2051392.83  107568.34
# 4  2015-11-29          0.99    3719603.21  1461861.54  1216811.00  104219.76
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year region
# 0  1410681.68   838267.79   567269.76      5144.13  conventional  2015   West
# 1  1274757.19   843691.13   417746.45     13319.61  conventional  2015   West
# 2  1370013.83   851506.76   517936.19       570.88  conventional  2015   West
# 3  1945832.15  1360760.83   582846.33      2224.99  conventional  2015   West
# 4   936710.91   688674.00   247318.15       718.76  conventional  2015   West

# %%
region_list=list(df.region.unique())
average_price=[]

for i in region_list:
    x=df[df.region==i]
    region_average=sum(x.AveragePrice)/len(x)
    average_price.append(region_average)

# %%
df1=pd.DataFrame({'region_list':region_list,'average_price':average_price})
df1.head()
# Out:
#            region_list  average_price
# 0               Albany       1.561036
# 1              Atlanta       1.337959
# 2  BaltimoreWashington       1.534231
# 3                Boise       1.348136
# 4               Boston       1.530888

# %%
new_index=df1.average_price.sort_values(ascending=False).index.values
sorted_data=df1.reindex(new_index)

plt.figure(figsize=(15,10))
ax=plt.bar(sorted_data.region_list,sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %%
x = df['AveragePrice']
y = df['Total Volume']
df2 = pd.DataFrame({'price':x,'volume':y})
df2.head(5)
# Out:
#    price     volume
# 0   1.33   64236.62
# 1   1.35   54876.98
# 2   0.93  118220.22
# 3   1.08   78992.15
# 4   1.28   51039.60

# %%
plt.scatter(y,x)
plt.ylabel('Average Price')
plt.xlabel('Total Volume')
plt.show()

# %%
df2.corr()
# Out:
#            price    volume
# price   1.000000 -0.192752
# volume -0.192752  1.000000

# %%
year_list = list(df.year.unique())
year_list
average_price =[]
for i in year_list:
    x=df[df.year==i]
    year_average=sum(x.AveragePrice)/len(x)
    average_price.append(year_average)
average_price
# Out:
# [1.3755903829029397, 1.3386396011395996, 1.515127577770011, 1.347530864197531]

# %%
plt.bar(year_list,average_price)
# Out:
# <BarContainer object of 4 artists>
